# %%
1. How do you distinguish between shutil.copy() and shutil.copytree()?

# %%
Ans: The shutil.copy() function will copy a single file, while shutil.copytree() will copy an entire folder, along with all its
     contents

# %%
2. What function is used to rename files??

# %%
Ans: shutil.move()

# %%
3. What is the difference between the delete functions in the send2trash and shutil modules?

# %%
Ans: send2trash will move a file or folder to the recycle bin, while shutil modules will premanently delete files and folders

# %%
4.ZipFile objects have a close() method just like File objects’ close() method. 
  What ZipFile method is equivalent to File objects’ open() method?

# %%
Ans: zipfile.ZipFile() function is equivalent to the open() function; the first argument is the file name and the second one is 
     the mode to open like read, write or append

# %%
5. Create a programme that searches a folder tree for files with a certain file extension 
  (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
Ans:--
