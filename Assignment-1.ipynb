# %%
1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
* 
'hello'
-87.8
- 
/ 
+	
6

# %%
Ans: In the given items, "hello",-87.8 and 6 are values whereas *,-,/ and + are expressions.

# %%
2. What is the difference between string and variable?

# %%
Ans: A string is a data type whereas a variable stores or holds a data

# %%
3. Describe three different data types.

# %%
Ans: the three data types are numeric,boolean and string
numeric - type of data which represents a numeric value, can be integer or float or complex number
string  - type of data which represents a collection of characters. All data types when given on double quotes will be taken as string
boolean-  is a conditional data type which represents whether a particular condition is True(1) or false(0)

# %%
4. What is an expression made up of? What do all expressions do?

# %%
Ans: Expression comprises of operators and operands. Expressions helps us to perform operation assigned to them

# %%
5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %%
Ans:  Expression contains operands and operators that are combined to create a new value. Statement is just a seperate self explainatory thing and doesn't return anything.

# %%
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

# %%
Ans: bacon=22

# %%
7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

# %%
Ans: For the both terms answer will be 'spamspamspam'

# %%
8. Why is eggs a valid variable name while 100 is invalid?

# %%
Ans: variable names cannot be values

# %%
9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
Ans: int(),float() and str()

# %%
10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos.'

# %%
Ans: We cannot concatenate string with an integer(99). It should be "I have eaten"+"burritos"
